# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- ------------------
# absl-py                           2.1.0
# aext-assistant                    4.1.0
# aext-assistant-server             4.1.0
# aext-core                         4.1.0
# aext-core-server                  4.1.0
# aext-panels                       4.1.0
# aext-panels-server                4.1.0
# aext-project-filebrowser-server   4.1.0
# aext-share-notebook               4.1.0
# aext-share-notebook-server        4.1.0
# aext-shared                       4.1.0
# aext-toolbox                      4.1.0
# aiobotocore                       2.12.3
# aiohappyeyeballs                  2.4.0
# aiohttp                           3.10.5
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# ale-py                            0.10.1
# alembic                           1.13.3
# altair                            5.0.1
# ...

# %%
# !pip install stable-baselines3[extra] protobuf==3.20.*

# %%
# !pip install mss pydirectinput pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 get_ipython().system('pip install mss pydirectinput pytesseract')
# ----> 2 pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
#
# NameError: name 'pytesseract' is not defined

# %%
from mss import mss
import pydirectinput
import cv2
import numpy as np
import pytesseract
from matplotlib import pyplot as plt
import time 
from gymnasium import Env
from gymnasium.spaces import Box, Discrete

# %%
from mss import mss
import pydirectinput
import cv2
import numpy as np
import pytesseract
from matplotlib import pyplot as plt
import time 
from gymnasium import Env
from gymnasium.spaces import Box, Discrete  # Updated for gymnasium

class WebGame(Env):
    def __init__(self):
        super().__init__()
        self.observation_space = Box(low=0, high=255, shape=(1, 83, 100), dtype=np.uint8)
        self.action_space = Discrete(3)  # Action space remains unchanged
        # Define extraction parameters for the game
        self.cap = mss()
        self.game_location = {'top': 300, 'left': 0, 'width': 600, 'height': 500}
        self.done_location = {'top': 405, 'left': 630, 'width': 660, 'height': 70}
        
    def step(self, action):
    # Action key - 0 = Space, 1 = Duck (down), 2 = No-op
        action_map = {
            0: 'space',
            1: 'down',
            2: 'no_op'
        }
        
    # Perform the action
        if action != 2:
            pydirectinput.press(action_map[action])
    # Get the observation and check for termination
        done, done_cap = self.get_done()
        observation = self.get_observation()
    # Reward remains unchanged
        reward = 1
    # `terminated` and `truncated` flags
        terminated = done  # The game is over when `done` is True
        truncated = False   # Assuming there's no time limit for this game (set to False)
        info = {}  # Additional info can be added if needed
        return observation, reward, terminated, truncated, info

    def render(self):
        cv2.imshow('Game', np.array(self.cap.grab(self.game_location))[:, :, :3])
        if cv2.waitKey(1) & 0xFF == ord('q'):
            self.close()
    
    def close(self):
        cv2.destroyAllWindows()

    def reset(self, seed=None, options=None):  # Updated to include seed argument for compatibility
        time.sleep(1)
        pydirectinput.click(x=150, y=400)
        pydirectinput.press('space')
        return self.get_observation(), {}  # Return observation and info (empty dictionary)

    def get_observation(self):
        raw = np.array(self.cap.grab(self.game_location))[:, :, :3]
        gray = cv2.cvtColor(raw, cv2.COLOR_BGR2GRAY)
        resized = cv2.resize(gray, (100, 83))
        channel = np.reshape(resized, (1, 83, 100))
        return channel

    # Get 'done' text using OCR
    def get_done(self):
        done_cap = np.array(self.cap.grab(self.done_location))
        done_strings = ['GAME', 'GAHE']
        done = False
        res = pytesseract.image_to_string(done_cap)[:4]
        if res in done_strings:
            done = True
        return done, done_cap

# %% [raw]
# TEST THE ENVIRONMENT

# %%
env = WebGame()

# %%
obs = env.get_observation()

# %%
plt.imshow(cv2.cvtColor(obs[0], cv2.COLOR_BGR2RGB))

# %%
done, done_cap = env.get_done()

# %%
plt.imshow(done_cap)

# %%
pytesseract.image_to_string(done_cap)[:4]
# Out:
# 'Gaws'

# %%
done
# Out:
# False

# %% [raw]
# TRAIN THE MODEL

# %%
import os
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common import env_checker
env = WebGame()

# %%
env_checker.check_env(env)
